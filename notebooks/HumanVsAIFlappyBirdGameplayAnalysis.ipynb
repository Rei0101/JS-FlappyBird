# %% [markdown]
# # AI Flappy Bird Analysis

# %% [markdown]
# ## Flappy Bird no-GUI game engine

# %% [markdown]
# ### Engine-specific imports and constants

# %%
import random
import time

GAME_WIDTH = 500
GAME_HEIGHT = 700

# %% [markdown]
# ### Bird class

# %%
class Bird:
  def __init__(self, game):
    self.game = game

    self.x = self.game.GAME_WIDTH / 2 - 50
    self._y = self.game.GAME_HEIGHT / 2 - 70

    self.width = 50
    self.height = 40

    self.gravity = 600
    self.velocity = 0

  @property
  def y(self):
    return self._y;
  @y.setter
  def y(self, v):
    if (v > self.game.GAME_HEIGHT or v < 0 - self.height):
      self.game.gameIsOver = True
    else:
     self._y = v;

  @property
  def hitbox(self):
    return {
      'x': self.x,
      'y': self.y,
      'width': self.width,
      'height': self.height,
    }

  def update(self, dt):
    self.fall(dt)

  def reset(self):
    self.x = self.game.GAME_WIDTH / 2 - 50
    self._y = self.game.GAME_HEIGHT / 2 - 70

    self.velocity = 0

  def fall(self, dt):
    self.velocity += self.gravity * dt
    self.y += self.velocity * dt

  def flapWings(self):
    self.velocity = -300

# %% [markdown]
# ### Pipes class

# %%
class Pipes:
  def __init__(self, game):
    self.game = game

    self.startPoint = 500

    self.gap = 200

    self._x = self.startPoint
    self.topY = random.random() * (self.game.GAME_HEIGHT - self.gap)
    self.botY = self.topY + self.gap

    self.width = 75
    self.topHeight = self.topY
    self.botHeight = self.game.GAME_HEIGHT - self.botY

    self.velocity = 100

    self.passed = False

  @property
  def x(self):
    return self._x
  @x.setter
  def x(self, v):
    if (v + self.width < 0):
      self.game.removePipePair(self)
    else:
      self._x = v

  @property
  def topHitbox(self):
    return {
      'x': self.x,
      'y': 0,
      'width': self.width,
      'height': self.topHeight,
    }
  @property
  def botHitbox(self):
    return {
      'x': self.x,
      'y': self.botY,
      'width': self.width,
      'height': self.botHeight,
    }

  def update(self, dt):
    self.x -= self.velocity * dt

  def reset(self):
    self.x = self.startPoint
    self.topY = random.random() * (self.game.GAME_HEIGHT - self.gap)
    self.botY = self.topY + self.gap

    self.topHeight = self.topY
    self.botHeight = self.game.GAME_HEIGHT - self.botY

# %% [markdown]
# ### Game class

# %%
class Game:
  def __init__(self, GAME_WIDTH, GAME_HEIGHT):
    self.accumulator = 0.0

    self.pipesInterval = 3
    self.flappingInterval = 0.5
    self.deltaTime = 0
    self.lastTime = None
    self.pipesElapsed = 0
    self.flappingElapsed = 0

    self.GAME_WIDTH = GAME_WIDTH
    self.GAME_HEIGHT = GAME_HEIGHT

    self.bird = Bird(self)
    self.pipes = []

    self.gameIsOver = False

    self.points = 0

  def update(self, dt):
    for pipePair in self.pipes:
      if self.areColliding(self.bird.hitbox, pipePair.topHitbox) or \
      self.areColliding(self.bird.hitbox, pipePair.botHitbox):
        self.gameIsOver = True
        return

      if not(pipePair.passed) and self.bird.x > pipePair.x:
        self.points += 1
        pipePair.passed = True

      pipePair.update(dt)
    self.bird.update(dt)

  def gameLoop(self):
    currentTime = time.time()
    if self.lastTime is None:
      self.lastTime = currentTime
    dt = currentTime - self.lastTime
    self.deltaTime = dt
    self.lastTime = currentTime

    FIXED_DT = 0.01667

    self.accumulator += dt

    while self.accumulator >= FIXED_DT:
      if not(self.gameIsOver):
        self.update(FIXED_DT)
      self.accumulator -= FIXED_DT

    if self.gameIsOver:
      return
    else:
      self.pipesElapsed += dt

      if self.pipesElapsed >= self.pipesInterval:
        self.addPipePair()
        self.pipesElapsed = 0

  def reset(self):
    self.deltaTime = 0
    self.lastTime = None
    self.pipesElapsed = 0
    self.flappingElapsed = 0

    self.bird.reset()

    self.pipes = []

    self.points = 0

  def addPipePair(self):
    pipePair = Pipes(self)
    self.pipes.append(pipePair)
  def removePipePair(self, pipePair):
    if pipePair in self.pipes:
      self.pipes.remove(pipePair)

  def areColliding(self, bird, pipe):
    return bird['x'] < pipe['x'] + pipe['width'] and \
      bird['x'] + bird['width'] > pipe['x'] and \
      bird['y'] < pipe['y'] + pipe['height'] and \
      bird['y'] + bird['height'] > pipe['y'] - 30

# %% [markdown]
# ## Game start!

# %%
game = Game(GAME_WIDTH, GAME_HEIGHT)

while not game.gameIsOver:
  game.gameLoop()

  print(f"Bird: x={game.bird.x}, y={game.bird.y}")
  print(f"Pipe pair number: {len(game.pipes)}")
  if len(game.pipes) > 0:
    print(f"1st pipe pair: x={game.pipes[0].x}, topY={game.pipes[0].topY}, botY={game.pipes[0].botY}")
  print(f"Points: {game.points}")
  print(f"Game is over: {game.gameIsOver}")
  print(f"Last time: {game.lastTime}")
  print(f"Delta time: {game.deltaTime}")
  print(f"Accumulator: {game.accumulator}")
  print("-" * 20)

  time.sleep(0.01667)
# Out:
# Bird: x=200.0, y=280.0
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.7532108
# Delta time: 0.0
# Accumulator: 0.0
# --------------------
# Bird: x=200.0, y=280.16673334
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.7702212
# Delta time: 0.01701045036315918
# Accumulator: 0.0003404503631591789
# --------------------
# Bird: x=200.0, y=280.50020002
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.7871838
# Delta time: 0.016962528228759766
# Accumulator: 0.0006329785919189437
# --------------------
# Bird: x=200.0, y=281.00040004000005
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.8041728
# Delta time: 0.01698899269104004
# Accumulator: 0.000951971282958982
# --------------------
# Bird: x=200.0, y=281.6673334
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.8211272
# Delta time: 0.016954421997070312
# Accumulator: 0.0012363932800292937
# --------------------
# Bird: x=200.0, y=282.5010001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.8381276
# Delta time: 0.017000436782836914
# Accumulator: 0.001566830062866207
# --------------------
# Bird: x=200.0, y=283.50140014
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.8551013
# Delta time: 0.01697373390197754
# Accumulator: 0.0018705639648437453
# --------------------
# Bird: x=200.0, y=284.66853352
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.8720148
# Delta time: 0.016913414001464844
# Accumulator: 0.0021139779663085882
# --------------------
# Bird: x=200.0, y=286.00240024
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.8890057
# Delta time: 0.01699090003967285
# Accumulator: 0.002434878005981439
# --------------------
# Bird: x=200.0, y=287.5030003
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.9060795
# Delta time: 0.017073869705200195
# Accumulator: 0.0028387477111816335
# --------------------
# Bird: x=200.0, y=289.1703337
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.9231088
# Delta time: 0.017029285430908203
# Accumulator: 0.003198033142089836
# --------------------
# Bird: x=200.0, y=291.00440044000004
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.9401116
# Delta time: 0.01700282096862793
# Accumulator: 0.0035308541107177648
# --------------------
# Bird: x=200.0, y=293.00520052
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.9570005
# Delta time: 0.016888856887817383
# Accumulator: 0.0037497109985351468
# --------------------
# Bird: x=200.0, y=295.17273394
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.9741986
# Delta time: 0.01719808578491211
# Accumulator: 0.004277796783447255
# --------------------
# Bird: x=200.0, y=297.5070007
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388026.9911358
# Delta time: 0.016937255859375
# Accumulator: 0.004545052642822255
# --------------------
# Bird: x=200.0, y=300.0080008
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.0081108
# Delta time: 0.016974925994873047
# Accumulator: 0.004849978637695301
# --------------------
# Bird: x=200.0, y=302.67573424
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.025087
# Delta time: 0.016976356506347656
# Accumulator: 0.005156335144042956
# --------------------
# Bird: x=200.0, y=305.51020102
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.0420268
# Delta time: 0.016939640045166016
# Accumulator: 0.005425975189208971
# --------------------
# Bird: x=200.0, y=308.51140114000003
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.0596004
# Delta time: 0.01757359504699707
# Accumulator: 0.0063295702362060405
# --------------------
# Bird: x=200.0, y=311.67933460000006
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.0765092
# Delta time: 0.016908884048461914
# Accumulator: 0.006568454284667954
# --------------------
# Bird: x=200.0, y=315.01400140000004
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.0934608
# Delta time: 0.016951560974121094
# Accumulator: 0.006850015258789047
# --------------------
# Bird: x=200.0, y=318.51540154
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.1104794
# Delta time: 0.017018556594848633
# Accumulator: 0.007198571853637679
# --------------------
# Bird: x=200.0, y=322.18353502
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.1275084
# Delta time: 0.0170290470123291
# Accumulator: 0.0075576188659667795
# --------------------
# Bird: x=200.0, y=326.01840184
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.144517
# Delta time: 0.017008543014526367
# Accumulator: 0.007896161880493146
# --------------------
# Bird: x=200.0, y=330.02000200000003
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.161457
# Delta time: 0.01694011688232422
# Accumulator: 0.008166278762817364
# --------------------
# Bird: x=200.0, y=334.18833550000005
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.1789734
# Delta time: 0.017516374588012695
# Accumulator: 0.009012653350830058
# --------------------
# Bird: x=200.0, y=338.5234023400001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.1959624
# Delta time: 0.01698899269104004
# Accumulator: 0.009331646041870097
# --------------------
# Bird: x=200.0, y=343.02520252000005
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.212944
# Delta time: 0.01698160171508789
# Accumulator: 0.009643247756957986
# --------------------
# Bird: x=200.0, y=347.69373604000003
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.2298605
# Delta time: 0.016916513442993164
# Accumulator: 0.00988976119995115
# --------------------
# Bird: x=200.0, y=352.5290029
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.2469158
# Delta time: 0.017055273056030273
# Accumulator: 0.010275034255981422
# --------------------
# Bird: x=200.0, y=357.5310031
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.2638671
# Delta time: 0.016951322555541992
# Accumulator: 0.010556356811523414
# --------------------
# Bird: x=200.0, y=362.69973664
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.2808325
# Delta time: 0.016965389251708984
# Accumulator: 0.010851746063232397
# --------------------
# Bird: x=200.0, y=368.03520352000004
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.297799
# Delta time: 0.016966581344604492
# Accumulator: 0.011148327407836889
# --------------------
# Bird: x=200.0, y=373.53740374000006
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.3149097
# Delta time: 0.017110586166381836
# Accumulator: 0.011588913574218724
# --------------------
# Bird: x=200.0, y=379.2063373000001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.3318844
# Delta time: 0.016974687576293945
# Accumulator: 0.011893601150512668
# --------------------
# Bird: x=200.0, y=385.04200420000006
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.3488731
# Delta time: 0.016988754272460938
# Accumulator: 0.012212355422973605
# --------------------
# Bird: x=200.0, y=391.04440444000005
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.3660345
# Delta time: 0.01716136932373047
# Accumulator: 0.012703724746704073
# --------------------
# Bird: x=200.0, y=397.21353802000004
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.3831117
# Delta time: 0.017077207565307617
# Accumulator: 0.01311093231201169
# --------------------
# Bird: x=200.0, y=403.54940494000004
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.4000833
# Delta time: 0.016971588134765625
# Accumulator: 0.013412520446777314
# --------------------
# Bird: x=200.0, y=410.05200520000005
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.4171062
# Delta time: 0.01702284812927246
# Accumulator: 0.013765368576049774
# --------------------
# Bird: x=200.0, y=416.72133880000007
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.434127
# Delta time: 0.01702094078063965
# Accumulator: 0.014116309356689422
# --------------------
# Bird: x=200.0, y=423.5574057400001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.4510982
# Delta time: 0.016971111297607422
# Accumulator: 0.014417420654296843
# --------------------
# Bird: x=200.0, y=430.5602060200001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.4680748
# Delta time: 0.016976594924926758
# Accumulator: 0.014724015579223596
# --------------------
# Bird: x=200.0, y=437.7297396400001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.4850848
# Delta time: 0.017009973526000977
# Accumulator: 0.015063989105224568
# --------------------
# Bird: x=200.0, y=445.0660066000001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.5020268
# Delta time: 0.01694202423095703
# Accumulator: 0.015336013336181595
# --------------------
# Bird: x=200.0, y=452.5690069000001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.5189254
# Delta time: 0.016898632049560547
# Accumulator: 0.015564645385742138
# --------------------
# Bird: x=200.0, y=460.2387405400001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.5358787
# Delta time: 0.016953229904174805
# Accumulator: 0.01584787528991694
# --------------------
# Bird: x=200.0, y=468.0752075200001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.5528545
# Delta time: 0.016975879669189453
# Accumulator: 0.016153754959106387
# --------------------
# Bird: x=200.0, y=476.0784078400001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.569702
# Delta time: 0.01684737205505371
# Accumulator: 0.016331127014160094
# --------------------
# Bird: x=200.0, y=484.24834150000015
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.5867023
# Delta time: 0.017000436782836914
# Accumulator: 0.016661563796997004
# --------------------
# Bird: x=200.0, y=501.08840884000017
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.6036284
# Delta time: 0.016926050186157227
# Accumulator: 0.0002476139831542254
# --------------------
# Bird: x=200.0, y=509.75854252000016
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.6207738
# Delta time: 0.017145395278930664
# Accumulator: 0.0007230092620848887
# --------------------
# Bird: x=200.0, y=518.5954095400002
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.637699
# Delta time: 0.01692509651184082
# Accumulator: 0.0009781057739257082
# --------------------
# Bird: x=200.0, y=527.5990099000002
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.6546218
# Delta time: 0.016922950744628906
# Accumulator: 0.0012310565185546136
# --------------------
# Bird: x=200.0, y=536.7693436000002
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.67151
# Delta time: 0.016888141632080078
# Accumulator: 0.001449198150634691
# --------------------
# Bird: x=200.0, y=546.1064106400001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.6884422
# Delta time: 0.016932249069213867
# Accumulator: 0.0017114472198485574
# --------------------
# Bird: x=200.0, y=555.6102110200002
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.7053602
# Delta time: 0.016917943954467773
# Accumulator: 0.00195939117431633
# --------------------
# Bird: x=200.0, y=565.2807447400002
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.7222297
# Delta time: 0.016869544982910156
# Accumulator: 0.0021589361572264855
# --------------------
# Bird: x=200.0, y=575.1180118000002
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.7391667
# Delta time: 0.0169370174407959
# Accumulator: 0.002425953598022383
# --------------------
# Bird: x=200.0, y=585.1220122000002
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.756099
# Delta time: 0.016932249069213867
# Accumulator: 0.0026882026672362495
# --------------------
# Bird: x=200.0, y=595.2927459400001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.7735941
# Delta time: 0.017495155334472656
# Accumulator: 0.003513358001708905
# --------------------
# Bird: x=200.0, y=605.6302130200002
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.790573
# Delta time: 0.016978740692138672
# Accumulator: 0.003822098693847576
# --------------------
# Bird: x=200.0, y=616.1344134400001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.807516
# Delta time: 0.01694321632385254
# Accumulator: 0.004095315017700114
# --------------------
# Bird: x=200.0, y=626.8053472000001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.8245075
# Delta time: 0.016991376876831055
# Accumulator: 0.004416691894531168
# --------------------
# Bird: x=200.0, y=637.6430143000001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.8414388
# Delta time: 0.01693129539489746
# Accumulator: 0.004677987289428628
# --------------------
# Bird: x=200.0, y=648.6474147400002
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.8583565
# Delta time: 0.016917705535888672
# Accumulator: 0.0049256928253172995
# --------------------
# Bird: x=200.0, y=659.8185485200001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.8753006
# Delta time: 0.016944169998168945
# Accumulator: 0.005199862823486244
# --------------------
# Bird: x=200.0, y=671.1564156400001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.892186
# Delta time: 0.01688528060913086
# Accumulator: 0.005415143432617103
# --------------------
# Bird: x=200.0, y=682.6610161000001
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.9090927
# Delta time: 0.01690673828125
# Accumulator: 0.005651881713867102
# --------------------
# Bird: x=200.0, y=694.3323499
# Pipe pair number: 0
# Points: 0
# Game is over: False
# Last time: 1767388027.9260519
# Delta time: 0.016959190368652344
# Accumulator: 0.005941072082519445
# --------------------
# Bird: x=200.0, y=694.3323499
# Pipe pair number: 0
# Points: 0
# Game is over: True
# Last time: 1767388027.9436018
# Delta time: 0.017549991607666016
# Accumulator: 0.00682106369018546
# --------------------

# %% [markdown]
# # NOTES
# - rekreirat u pythonu js game bez GUIa jer je tu bolje ai radit i da iman sve za posli analizu
# - proba san fps based na oba ali je bolje timebased da bude fair game
